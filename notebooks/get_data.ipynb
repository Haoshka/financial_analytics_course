# %%
# import yfinance as yf
# import pandas as pd
# import time

# # List of crypto-related tickers
# tickers = [
#     "MSTR",   # MicroStrategy
#     "GLXY.TO",# Galaxy Digital (Toronto-listed)
#     "3350.T", # Metaplanet Inc (Tokyo Stock Exchange)
#     "COIN",   # Coinbase
#     "RIOT",   # Riot Platforms
#     "MARA",   # Marathon Digital
#     "CLSK",   # CleanSpark
#     "WULF",   # TeraWulf
#     "CORZ",   # Core Scientific
#     "BTDR"    # Bitdeer Technologies (NASDAQ) – you can swap with HIVE.V if preferred
# ]

# # Dictionary to store DataFrames
# price_data = {}

# for ticker in tickers:
#     print(f"Downloading {ticker}...")
#     ticker_obj = yf.Ticker(ticker)
#     try:
#         historyPrices = ticker_obj.history(
#             period="5y",
#             interval="1d",
#             threads=False  # Avoid multi-threaded requests which trigger rate limit
#         )
#         price_data[ticker] = historyPrices
#         print(f"{ticker} downloaded: {len(historyPrices)} rows")
#     except Exception as e:
#         print(f"Error downloading {ticker}: {e}")
#     time.sleep(5)  # Pause 5 seconds between requests to prevent rate limit

# Optionally: Combine into one Excel file with a sheet per ticker
# with pd.ExcelWriter("crypto_stocks_5y.xlsx") as writer:
#     for ticker, df in price_data.items():
#         df.to_excel(writer, sheet_name=ticker)

# %%
import pandas_datareader as pdr

import pandas as pd
import numpy as np

from datetime import datetime
import datetime

import matplotlib.pyplot as plt

from pathlib import Path

# %%
# Define the start and end dates for the data retrieval
start_date = '2020-01-01'
end_date = '2025-08-01'
#end_date

# %% [markdown]
# # FRED Macroeconomic Indicators

# %%
def get_fred_macro_data(fred_series, start_date, end_date):
    """
    Fetch FRED macroeconomic data, compute YoY and QoQ changes,
    and return a single merged DataFrame resampled to quarter-end.

    Parameters:
    - fred_series: dict of {friendly_name: FRED_series_code}
    - start_date, end_date: date strings in 'YYYY-MM-DD' format

    Returns:
    - macro_df: DataFrame with macro features per quarter
    """
    fred_data = {}

    for name, code in fred_series.items():
        try:
            df = pdr.DataReader(code, "fred", start=start_date, end=end_date)
            if df.empty:
                print(f"[FRED] No data for {name} ({code}), skipping.")
                continue
            # YoY and QoQ percentage changes
            df[name + '_yoy'] = df[code].pct_change(4)
            df[name + '_qoq'] = df[code].pct_change(1)

            # Rename column to friendly name
            df = df.rename(columns={code: name})

            fred_data[name] = df

        except Exception as e:
            print(f"[FRED] Error for {name} ({code}): {e}")
            continue

    if not fred_data:
        print("No FRED data retrieved.")
        return pd.DataFrame()

    # Merge and resample to quarter-end
    macro_df = pd.concat(fred_data.values(), axis=1).resample('QE').last()
    

    # Extract year and quarter for joining with other datasets
    macro_df = macro_df.reset_index()
    macro_df['year'] = macro_df['DATE'].dt.year
    macro_df['quarter'] = macro_df['DATE'].dt.quarter
    macro_df = macro_df.rename(columns={'DATE': 'date'})
    return macro_df

# %%
fred_series = {
    'gdp_us': 'GDPC1',
    'cpi_us': 'CPIAUCSL',
    'unemployment_us': 'UNRATE',
    'interest_us': 'FEDFUNDS',
    'gdp_de': 'CLVMNACSCAB1GQDE',
    'cpi_de': 'DEUCPIALLMINMEI',
    'interest_eu': 'IRLTLT01EZM156N'
}

# %%
macro_df = get_fred_macro_data(fred_series, start_date, end_date)
macro_df.tail()
# Out:
#          date     gdp_us  gdp_us_yoy  gdp_us_qoq   cpi_us  cpi_us_yoy  \
# 18 2024-09-30  23400.294    0.027188    0.007595  314.851    0.005464
# 19 2024-12-31  23542.349    0.025337    0.006071  317.603    0.011053
# 20 2025-03-31  23512.717    0.019918   -0.001259  319.615    0.010005
# 21 2025-06-30  23703.782    0.020663    0.008126  321.500    0.005394
# 22 2025-09-30        NaN         NaN         NaN  323.364    0.009500
#
#     cpi_us_qoq  unemployment_us  unemployment_us_yoy  unemployment_us_qoq  \
# 18    0.002292              4.1              0.02500             -0.02381
# 19    0.003647              4.1             -0.02381             -0.02381
# 20   -0.000500              4.2              0.00000              0.02439
# 21    0.002870              4.1              0.00000             -0.02381
# 22    0.003825              4.3              0.02381              0.02381
#
#     ...  gdp_de_yoy  gdp_de_qoq    cpi_de  cpi_de_yoy  cpi_de_qoq  \
# 18  ...   -0.006217    0.000192  126.1978    0.003353    0.000000
# 19  ...   -0.001648    0.001822  127.0412    0.006683    0.005004
# 20  ...    0.002487    0.003062  127.7792    0.010843    0.003311
# 21  ...    0.002301   -0.002767       NaN         NaN         NaN
# 22  ...         NaN         NaN       NaN         NaN         NaN
#
#     interest_eu  interest_eu_yoy  interest_eu_qoq  year  quarter
# 18     2.834165        -0.092048        -0.024690  2024        3
# 19     2.812343        -0.032200        -0.039871  2024        4
# 20     3.313772         0.131316         0.108784  2025        1
# 21     3.084761         0.032157         0.004483  2025        2
# 22     3.173563        -0.042311         0.028787  2025        3
#
# [5 rows x 24 columns]

# %%
macro_df.rename(columns={'date': 'quarter_end'}, inplace=True)

# %%
df_crypto = pd.read_csv('multi_crypto.csv', parse_dates=['timestamp'])

# %%
df_crypto.rename(columns={'timestamp': 'date'}, inplace=True)

# %%
#df_crypto.drop(columns=['open', 'high', 'low'], inplace=True)

# %%
# Data preprocessing

# %%
def get_price_features(df):
        df = df.copy()

        #drop unused columns
        df.columns = df.columns.str.lower()
        df.drop(columns=['open', 'high', 'low'], inplace=True)

        # 1. Log of Volume (avoid log(0) by replacing 0 with NaN)
        df['ln_volume'] = np.log(df['volume'].replace(0, np.nan))

        # 2. Median growth rates
        df['daily_growth'] = df['close'] / df['close'].shift(1)
        df['weekly_growth'] = df['close'] / df['close'].shift(7)
        df['monthly_growth'] = df['close'] / df['close'].shift(30)

        # 3. Rolling volatility
        df['vol_weekly'] = df['close'].pct_change().rolling(7).std()
        df['momentum_weekly'] = df['weekly_growth'] / df['vol_weekly']

        # 4. moving averages
        df['ma_20'] = df['close'].rolling(window=20).mean()
        df['ma_50'] = df['close'].rolling(window=50).mean()
        df['ma_100'] = df['close'].rolling(window=100).mean()

        # 5. Add metadata
        df['year'] = df['date'].dt.year
        df['quarter'] = df['date'].dt.quarter
        df["quarter_end"] = df["date"] + pd.offsets.QuarterEnd(0)
        
        return df

# %%
#df_crypto['Date'] = pd.to_datetime(df_crypto['Date'])

df_crypto_clean = (
    df_crypto
    .groupby('ticker', group_keys=False)
    .apply(get_price_features)
    .reset_index(drop=True)
)
# Out:
# C:\Users\HAOZHENG\AppData\Local\Temp\ipykernel_15672\2883351901.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(get_price_features)

# %%
df_crypto_clean.head(10).T
# Out:
#                                    0                    1  \
# date             2021-01-01 00:00:00  2021-01-01 00:00:00
# close                       29331.69               728.91
# volume                  54182.925011         675114.09329
# ticker                      BTC/USDT             ETH/USDT
# ln_volume                  10.900121            13.422637
# daily_growth                     NaN                  NaN
# weekly_growth                    NaN                  NaN
# monthly_growth                   NaN                  NaN
# vol_weekly                       NaN                  NaN
# momentum_weekly                  NaN                  NaN
# ma_20                            NaN                  NaN
# ma_50                            NaN                  NaN
# ma_100                           NaN                  NaN
# year                            2021                 2021
# quarter                            1                    1
# quarter_end      2021-03-31 00:00:00  2021-03-31 00:00:00
#
#                                    2                    3  \
# date             2021-01-01 00:00:00  2021-01-02 00:00:00
# close                         1.8421             32178.33
# volume                    4421991.45        129993.873362
# ticker                      SOL/USDT             BTC/USDT
# ln_volume                  15.302101            11.775243
# daily_growth                     NaN              1.09705
# weekly_growth                    NaN                  NaN
# monthly_growth                   NaN                  NaN
# vol_weekly                       NaN                  NaN
# momentum_weekly                  NaN                  NaN
# ma_20                            NaN                  NaN
# ma_50                            NaN                  NaN
# ma_100                           NaN                  NaN
# year                            2021                 2021
# quarter                            1                    1
# quarter_end      2021-03-31 00:00:00  2021-03-31 00:00:00
#
#                                    4                    5  \
# date             2021-01-02 00:00:00  2021-01-02 00:00:00
# close                         774.56               1.7999
# volume                 1352618.57668           5253819.62
# ticker                      ETH/USDT             SOL/USDT
# ln_volume                  14.117553            15.474466
# daily_growth                1.062628             0.977091
# weekly_growth                    NaN                  NaN
# monthly_growth                   NaN                  NaN
# vol_weekly                       NaN                  NaN
# momentum_weekly                  NaN                  NaN
# ma_20                            NaN                  NaN
# ma_50                            NaN                  NaN
# ma_100                           NaN                  NaN
# year                            2021                 2021
# quarter                            1                    1
# quarter_end      2021-03-31 00:00:00  2021-03-31 00:00:00
#
#                                    6                    7  \
# date             2021-01-03 00:00:00  2021-01-03 00:00:00
# close                       33000.05               978.28
# volume                  120957.56675        2813603.88615
# ticker                      BTC/USDT             ETH/USDT
# ln_volume                  11.703195            14.849977
# daily_growth                1.025536             1.263014
# weekly_growth                    NaN                  NaN
# monthly_growth                   NaN                  NaN
# vol_weekly                       NaN                  NaN
# momentum_weekly                  NaN                  NaN
# ma_20                            NaN                  NaN
# ma_50                            NaN                  NaN
# ma_100                           NaN                  NaN
# year                            2021                 2021
# quarter                            1                    1
# quarter_end      2021-03-31 00:00:00  2021-03-31 00:00:00
#
#                                    8                    9
# date             2021-01-03 00:00:00  2021-01-04 00:00:00
# close                         2.1779             31988.71
# volume                    8318341.13         140899.88569
# ticker                      SOL/USDT             BTC/USDT
# ln_volume                  15.933973            11.855805
# daily_growth                1.210012             0.969353
# weekly_growth                    NaN                  NaN
# monthly_growth                   NaN                  NaN
# vol_weekly                       NaN                  NaN
# momentum_weekly                  NaN                  NaN
# ma_20                            NaN                  NaN
# ma_50                            NaN                  NaN
# ma_100                           NaN                  NaN
# year                            2021                 2021
# quarter                            1                    1
# quarter_end      2021-03-31 00:00:00  2021-03-31 00:00:00

# %%
df_stock = pd.read_csv('CryptoEquities_OHLCV.csv', parse_dates=['Date'])

# %%
df_stock = df_stock[df_stock['Ticker'].apply(lambda x: x in ['MSTR', 'COIN', 'RIOT', 'MARA', 'CLSK', 'WULF'])].reset_index(drop=True)

# %%
#df_stock['Date'] = pd.to_datetime(df_stock['Date'])

df_stock_clean = (
    df_stock
    .groupby('Ticker', group_keys=False)
    .apply(get_price_features)
    .reset_index(drop=True)
)
# Out:
# C:\Users\HAOZHENG\AppData\Local\Temp\ipykernel_15672\3609911749.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(get_price_features)

# %%
# FUTURE Growth: for binary models
df_stock_clean['positive_weekly_growth'] = np.where(df_stock_clean['weekly_growth'] > 1, 1, 0)

# %%
df_stock_clean['positive_weekly_growth'].value_counts()
# Out:
# positive_weekly_growth
# 0    3606
# 1    3344
# Name: count, dtype: int64

# %%
df_stock_clean.head(10).T
# Out:
#                                           0                    1  \
# date                    2021-01-04 00:00:00  2021-01-05 00:00:00
# close                                42.522               42.863
# volume                             14679020             11006240
# ticker                                 MSTR                 MSTR
# ln_volume                          16.50193            16.213973
# daily_growth                            NaN             1.008019
# weekly_growth                           NaN                  NaN
# monthly_growth                          NaN                  NaN
# vol_weekly                              NaN                  NaN
# momentum_weekly                         NaN                  NaN
# ma_20                                   NaN                  NaN
# ma_50                                   NaN                  NaN
# ma_100                                  NaN                  NaN
# year                                   2021                 2021
# quarter                                   1                    1
# quarter_end             2021-03-31 00:00:00  2021-03-31 00:00:00
# positive_weekly_growth                    0                    0
#
#                                           2                    3  \
# date                    2021-01-06 00:00:00  2021-01-07 00:00:00
# close                                48.055               53.575
# volume                             15360310             22844050
# ticker                                 MSTR                 MSTR
# ln_volume                         16.547297            16.944201
# daily_growth                        1.12113             1.114868
# weekly_growth                           NaN                  NaN
# monthly_growth                          NaN                  NaN
# vol_weekly                              NaN                  NaN
# momentum_weekly                         NaN                  NaN
# ma_20                                   NaN                  NaN
# ma_50                                   NaN                  NaN
# ma_100                                  NaN                  NaN
# year                                   2021                 2021
# quarter                                   1                    1
# quarter_end             2021-03-31 00:00:00  2021-03-31 00:00:00
# positive_weekly_growth                    0                    0
#
#                                           4                    5  \
# date                    2021-01-08 00:00:00  2021-01-11 00:00:00
# close                                53.164               49.549
# volume                             16453870             14856440
# ticker                                 MSTR                 MSTR
# ln_volume                         16.616071            16.513944
# daily_growth                       0.992329             0.932003
# weekly_growth                           NaN                  NaN
# monthly_growth                          NaN                  NaN
# vol_weekly                              NaN                  NaN
# momentum_weekly                         NaN                  NaN
# ma_20                                   NaN                  NaN
# ma_50                                   NaN                  NaN
# ma_100                                  NaN                  NaN
# year                                   2021                 2021
# quarter                                   1                    1
# quarter_end             2021-03-31 00:00:00  2021-03-31 00:00:00
# positive_weekly_growth                    0                    0
#
#                                           6                    7  \
# date                    2021-01-12 00:00:00  2021-01-13 00:00:00
# close                                51.424               51.926
# volume                              6717660              6174580
# ticker                                 MSTR                 MSTR
# ln_volume                          15.72025            15.635951
# daily_growth                       1.037841             1.009762
# weekly_growth                           NaN             1.221156
# monthly_growth                          NaN                  NaN
# vol_weekly                              NaN             0.067675
# momentum_weekly                         NaN            18.044539
# ma_20                                   NaN                  NaN
# ma_50                                   NaN                  NaN
# ma_100                                  NaN                  NaN
# year                                   2021                 2021
# quarter                                   1                    1
# quarter_end             2021-03-31 00:00:00  2021-03-31 00:00:00
# positive_weekly_growth                    0                    1
#
#                                           8                    9
# date                    2021-01-14 00:00:00  2021-01-15 00:00:00
# close                                  63.1               57.807
# volume                             19117760             16088990
# ticker                                 MSTR                 MSTR
# ln_volume                         16.766128            16.593646
# daily_growth                       1.215191             0.916117
# weekly_growth                      1.472132             1.202934
# monthly_growth                          NaN                  NaN
# vol_weekly                         0.095575             0.104843
# momentum_weekly                   15.402855            11.473716
# ma_20                                   NaN                  NaN
# ma_50                                   NaN                  NaN
# ma_100                                  NaN                  NaN
# year                                   2021                 2021
# quarter                                   1                    1
# quarter_end             2021-03-31 00:00:00  2021-03-31 00:00:00
# positive_weekly_growth                    1                    1

# %%
macro_df.columns
# Out:
# Index(['quarter_end', 'gdp_us', 'gdp_us_yoy', 'gdp_us_qoq', 'cpi_us',
#        'cpi_us_yoy', 'cpi_us_qoq', 'unemployment_us', 'unemployment_us_yoy',
#        'unemployment_us_qoq', 'interest_us', 'interest_us_yoy',
#        'interest_us_qoq', 'gdp_de', 'gdp_de_yoy', 'gdp_de_qoq', 'cpi_de',
#        'cpi_de_yoy', 'cpi_de_qoq', 'interest_eu', 'interest_eu_yoy',
#        'interest_eu_qoq', 'year', 'quarter'],
#       dtype='object')

# %%
final_df = pd.DataFrame()

# %%
for crypto in df_crypto_clean['ticker'].unique():

    df_temp_crypto = df_crypto_clean[df_crypto_clean['ticker'] == crypto].copy()

    # Merge crypto and stock data on date
    df_merged = pd.merge(
            df_temp_crypto,
            df_stock_clean,
            on=['date', 'quarter_end', 'year', 'quarter'],
            suffixes=('_crypto', '_stock'),
            how = 'left'
    )
    final_df = pd.concat([final_df, df_merged], ignore_index=True)

# %%
final_df[final_df["ticker_crypto"] == "ETH/USDT"].head(10).T
# Out:
#                                        7485                 7486  \
# date                    2021-01-01 00:00:00  2021-01-02 00:00:00
# close_crypto                         728.91               774.56
# volume_crypto                  675114.09329        1352618.57668
# ticker_crypto                      ETH/USDT             ETH/USDT
# ln_volume_crypto                  13.422637            14.117553
# daily_growth_crypto                     NaN             1.062628
# weekly_growth_crypto                    NaN                  NaN
# monthly_growth_crypto                   NaN                  NaN
# vol_weekly_crypto                       NaN                  NaN
# momentum_weekly_crypto                  NaN                  NaN
# ma_20_crypto                            NaN                  NaN
# ma_50_crypto                            NaN                  NaN
# ma_100_crypto                           NaN                  NaN
# year                                   2021                 2021
# quarter                                   1                    1
# quarter_end             2021-03-31 00:00:00  2021-03-31 00:00:00
# close_stock                             NaN                  NaN
# volume_stock                            NaN                  NaN
# ticker_stock                            NaN                  NaN
# ln_volume_stock                         NaN                  NaN
# daily_growth_stock                      NaN                  NaN
# weekly_growth_stock                     NaN                  NaN
# monthly_growth_stock                    NaN                  NaN
# vol_weekly_stock                        NaN                  NaN
# momentum_weekly_stock                   NaN                  NaN
# ma_20_stock                             NaN                  NaN
# ma_50_stock                             NaN                  NaN
# ma_100_stock                            NaN                  NaN
# positive_weekly_growth                  NaN                  NaN
#
#                                        7487                 7488  \
# date                    2021-01-03 00:00:00  2021-01-04 00:00:00
# close_crypto                         978.28              1041.43
# volume_crypto                 2813603.88615        4245010.94004
# ticker_crypto                      ETH/USDT             ETH/USDT
# ln_volume_crypto                  14.849977            15.261255
# daily_growth_crypto                1.263014             1.064552
# weekly_growth_crypto                    NaN                  NaN
# monthly_growth_crypto                   NaN                  NaN
# vol_weekly_crypto                       NaN                  NaN
# momentum_weekly_crypto                  NaN                  NaN
# ma_20_crypto                            NaN                  NaN
# ma_50_crypto                            NaN                  NaN
# ma_100_crypto                           NaN                  NaN
# year                                   2021                 2021
# quarter                                   1                    1
# quarter_end             2021-03-31 00:00:00  2021-03-31 00:00:00
# close_stock                             NaN               42.522
# volume_stock                            NaN           14679020.0
# ticker_stock                            NaN                 MSTR
# ln_volume_stock                         NaN             16.50193
# daily_growth_stock                      NaN                  NaN
# weekly_growth_stock                     NaN                  NaN
# monthly_growth_stock                    NaN                  NaN
# vol_weekly_stock                        NaN                  NaN
# momentum_weekly_stock                   NaN                  NaN
# ma_20_stock                             NaN                  NaN
# ma_50_stock                             NaN                  NaN
# ma_100_stock                            NaN                  NaN
# positive_weekly_growth                  NaN                  0.0
#
#                                        7489                 7490  \
# date                    2021-01-04 00:00:00  2021-01-04 00:00:00
# close_crypto                        1041.43              1041.43
# volume_crypto                 4245010.94004        4245010.94004
# ticker_crypto                      ETH/USDT             ETH/USDT
# ln_volume_crypto                  15.261255            15.261255
# daily_growth_crypto                1.064552             1.064552
# weekly_growth_crypto                    NaN                  NaN
# monthly_growth_crypto                   NaN                  NaN
# vol_weekly_crypto                       NaN                  NaN
# momentum_weekly_crypto                  NaN                  NaN
# ma_20_crypto                            NaN                  NaN
# ma_50_crypto                            NaN                  NaN
# ma_100_crypto                           NaN                  NaN
# year                                   2021                 2021
# quarter                                   1                    1
# quarter_end             2021-03-31 00:00:00  2021-03-31 00:00:00
# close_stock                           16.48                11.01
# volume_stock                     32293631.0           35826550.0
# ticker_stock                           RIOT                 MARA
# ln_volume_stock                   17.290381              17.3942
# daily_growth_stock                      NaN                  NaN
# weekly_growth_stock                     NaN                  NaN
# monthly_growth_stock                    NaN                  NaN
# vol_weekly_stock                        NaN                  NaN
# momentum_weekly_stock                   NaN                  NaN
# ma_20_stock                             NaN                  NaN
# ma_50_stock                             NaN                  NaN
# ma_100_stock                            NaN                  NaN
# positive_weekly_growth                  0.0                  0.0
#
#                                        7491                 7492  \
# date                    2021-01-04 00:00:00  2021-01-04 00:00:00
# close_crypto                        1041.43              1041.43
# volume_crypto                 4245010.94004        4245010.94004
# ticker_crypto                      ETH/USDT             ETH/USDT
# ln_volume_crypto                  15.261255            15.261255
# daily_growth_crypto                1.064552             1.064552
# weekly_growth_crypto                    NaN                  NaN
# monthly_growth_crypto                   NaN                  NaN
# vol_weekly_crypto                       NaN                  NaN
# momentum_weekly_crypto                  NaN                  NaN
# ma_20_crypto                            NaN                  NaN
# ma_50_crypto                            NaN                  NaN
# ma_100_crypto                           NaN                  NaN
# year                                   2021                 2021
# quarter                                   1                    1
# quarter_end             2021-03-31 00:00:00  2021-03-31 00:00:00
# close_stock                           26.66                 9.67
# volume_stock                      2844722.0              27944.0
# ticker_stock                           CLSK                 WULF
# ln_volume_stock                   14.860976            10.237958
# daily_growth_stock                      NaN                  NaN
# weekly_growth_stock                     NaN                  NaN
# monthly_growth_stock                    NaN                  NaN
# vol_weekly_stock                        NaN                  NaN
# momentum_weekly_stock                   NaN                  NaN
# ma_20_stock                             NaN                  NaN
# ma_50_stock                             NaN                  NaN
# ma_100_stock                            NaN                  NaN
# positive_weekly_growth                  0.0                  0.0
#
#                                        7493                 7494
# date                    2021-01-05 00:00:00  2021-01-05 00:00:00
# close_crypto                        1099.56              1099.56
# volume_crypto                 2706995.67525        2706995.67525
# ticker_crypto                      ETH/USDT             ETH/USDT
# ln_volume_crypto                   14.81135             14.81135
# daily_growth_crypto                1.055817             1.055817
# weekly_growth_crypto                    NaN                  NaN
# monthly_growth_crypto                   NaN                  NaN
# vol_weekly_crypto                       NaN                  NaN
# momentum_weekly_crypto                  NaN                  NaN
# ma_20_crypto                            NaN                  NaN
# ma_50_crypto                            NaN                  NaN
# ma_100_crypto                           NaN                  NaN
# year                                   2021                 2021
# quarter                                   1                    1
# quarter_end             2021-03-31 00:00:00  2021-03-31 00:00:00
# close_stock                          42.863                18.41
# volume_stock                     11006240.0           28099781.0
# ticker_stock                           MSTR                 RIOT
# ln_volume_stock                   16.213973            17.151272
# daily_growth_stock                 1.008019             1.117112
# weekly_growth_stock                     NaN                  NaN
# monthly_growth_stock                    NaN                  NaN
# vol_weekly_stock                        NaN                  NaN
# momentum_weekly_stock                   NaN                  NaN
# ma_20_stock                             NaN                  NaN
# ma_50_stock                             NaN                  NaN
# ma_100_stock                            NaN                  NaN
# positive_weekly_growth                  0.0                  0.0

# %%
all_data = pd.merge(final_df, macro_df,
                    on = ['quarter_end', 'year', 'quarter'],
                    how = 'left')

# %%
all_data.to_csv('all_data_raw.csv', index=False)

# %%
all_data#.info()
# Out:
#             date  close_crypto  volume_crypto ticker_crypto  ln_volume_crypto  \
# 0     2021-01-01      29331.69   5.418293e+04      BTC/USDT         10.900121
# 1     2021-01-02      32178.33   1.299939e+05      BTC/USDT         11.775243
# 2     2021-01-03      33000.05   1.209576e+05      BTC/USDT         11.703195
# 3     2021-01-04      31988.71   1.408999e+05      BTC/USDT         11.855805
# 4     2021-01-04      31988.71   1.408999e+05      BTC/USDT         11.855805
# ...          ...           ...            ...           ...               ...
# 22450 2025-08-29        205.08   8.607487e+06      SOL/USDT         15.968143
# 22451 2025-08-29        205.08   8.607487e+06      SOL/USDT         15.968143
# 22452 2025-08-30        202.70   3.894576e+06      SOL/USDT         15.175095
# 22453 2025-08-31        200.62   3.303224e+06      SOL/USDT         15.010410
# 22454 2025-09-01        199.78   3.636211e+06      SOL/USDT         15.106453
#
#        daily_growth_crypto  weekly_growth_crypto  monthly_growth_crypto  \
# 0                      NaN                   NaN                    NaN
# 1                 1.097050                   NaN                    NaN
# 2                 1.025536                   NaN                    NaN
# 3                 0.969353                   NaN                    NaN
# 4                 0.969353                   NaN                    NaN
# ...                    ...                   ...                    ...
# 22450             0.956396              1.021875               1.153625
# 22451             0.956396              1.021875               1.153625
# 22452             0.988395              0.992946               1.176983
# 22453             0.989739              0.973978               1.232991
# 22454             0.995813              1.067201               1.260601
#
#        vol_weekly_crypto  momentum_weekly_crypto  ...  interest_us_qoq  \
# 0                    NaN                     NaN  ...           -0.125
# 1                    NaN                     NaN  ...           -0.125
# 2                    NaN                     NaN  ...           -0.125
# 3                    NaN                     NaN  ...           -0.125
# 4                    NaN                     NaN  ...           -0.125
# ...                  ...                     ...  ...              ...
# 22450           0.053398               19.136770  ...            0.000
# 22451           0.053398               19.136770  ...            0.000
# 22452           0.053354               18.610669  ...            0.000
# 22453           0.053323               18.265798  ...            0.000
# 22454           0.036791               29.007029  ...            0.000
#
#          gdp_de  gdp_de_yoy  gdp_de_qoq    cpi_de cpi_de_yoy  cpi_de_qoq  \
# 0      743509.0   -0.006255   -0.006158  107.6424   0.024072    0.004922
# 1      743509.0   -0.006255   -0.006158  107.6424   0.024072    0.004922
# 2      743509.0   -0.006255   -0.006158  107.6424   0.024072    0.004922
# 3      743509.0   -0.006255   -0.006158  107.6424   0.024072    0.004922
# 4      743509.0   -0.006255   -0.006158  107.6424   0.024072    0.004922
# ...         ...         ...         ...       ...        ...         ...
# 22450       NaN         NaN         NaN       NaN        NaN         NaN
# 22451       NaN         NaN         NaN       NaN        NaN         NaN
# 22452       NaN         NaN         NaN       NaN        NaN         NaN
# 22453       NaN         NaN         NaN       NaN        NaN         NaN
# 22454       NaN         NaN         NaN       NaN        NaN         NaN
#
#        interest_eu interest_eu_yoy  interest_eu_qoq
# 0         0.147856       -3.686229         1.339151
# 1         0.147856       -3.686229         1.339151
# 2         0.147856       -3.686229         1.339151
# 3         0.147856       -3.686229         1.339151
# 4         0.147856       -3.686229         1.339151
# ...            ...             ...              ...
# 22450     3.173563       -0.042311         0.028787
# 22451     3.173563       -0.042311         0.028787
# 22452     3.173563       -0.042311         0.028787
# 22453     3.173563       -0.042311         0.028787
# 22454     3.173563       -0.042311         0.028787
#
# [22455 rows x 50 columns]
